# %%
# %load_ext autoreload
# %autoreload 2

# Agregar src/ al path
import sys
sys.path.append("/Workspace/Repos/desareca/santiago-weather-forecast")

from src.data.ingestion import fetch_weather_data, save_to_delta_table
from src.utils.config import *

print("✅ Módulos importados correctamente")
# Out:
# ✅ Módulos importados correctamente

# %%
# Usar función del módulo
df = fetch_weather_data(
    latitude=LATITUDE,
    longitude=LONGITUDE,
    start_date=START_DATE,
    end_date=END_DATE,
    daily_variables=DAILY_VARIABLES,
    hourly_variables=HOURLY_VARIABLES,
    hourly_aggregations=HOURLY_AGGREGATIONS,
    timezone=TIMEZONE,
    add_derived=True,
)

display(df.head())
# Out:
# 📡 [daily] Descargando 11 variables (2016-01-01 → 2025-12-31)...
# ✅ [daily] 3653 registros | 11 variables
# 📡 [hourly] Descargando 12 variables (2016-01-01 → 2025-12-31)...
# ✅ [hourly] 87672 registros horarios | 12 variables
# ✅ [aggregate] 3653 días | 20 columnas agregadas
# ✅ [merge] Shape tras merge: (3653, 32)
# ✅ [derived] 6 features derivadas: ['pressure_trend_24h', 'pressure_trend_48h', 'pressure_range', 'wind_west_component', 'wind_north_component', 'rh_vpd_interaction']
#
# ✅ Dataset final: 3653 días | 38 columnas
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fecha</th><th>precipitation_sum</th><th>precipitation_hours</th><th>temperature_2m_max</th><th>temperature_2m_min</th><th>temperature_2m_mean</th><th>windspeed_10m_max</th><th>windgusts_10m_max</th><th>winddirection_10m_dominant</th><th>shortwave_radiation_sum</th><th>et0_fao_evapotranspiration</th><th>weathercode</th><th>pressure_msl_mean</th><th>pressure_msl_min</th><th>pressure_msl_max</th><th>surface_pressure_mean</th><th>relative_humidity_2m_mean</th><th>relative_humidity_2m_max</th><th>dew_point_2m_mean</th><th>dew_point_2m_min</th><th>vapour_pressure_deficit_mean</th><th>vapour_pressure_deficit_min</th><th>cloud_cover_mean</th><th>cloud_cover_max</th><th>cloud_cover_low_mean</th><th>cloud_cover_low_max</th><th>cloud_cover_mid_mean</th><th>cloud_cover_high_mean</th><th>wind_speed_10m_mean</th><th>wind_speed_10m_max</th><th>wind_direction_10m_mean</th><th>wind_gusts_10m_max</th><th>pressure_trend_24h</th><th>pressure_trend_48h</th><th>pressure_range</th><th>wind_west_component</th><th>wind_north_component</th><th>rh_vpd_interaction</th></tr></thead><tbody><tr><td>2016-01-01T00:00:00.000Z</td><td>0.0</td><td>0.0</td><td>28.5</td><td>16.7</td><td>21.8</td><td>13.7</td><td>31.7</td><td>244</td><td>32.91</td><td>6.67</td><td>3</td><td>1009.3791666666666</td><td>1008.0</td><td>1012.1</td><td>950.375</td><td>53.958333333333336</td><td>74</td><td>11.4625</td><td>10.7</
...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3653 entries, 0 to 3652
# Data columns (total 38 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fecha                         3653 non-null   datetime64[ns]
#  1   precipitation_sum             3653 non-null   float64
#  2   precipitation_hours           3653 non-null   float64
#  3   temperature_2m_max            3653 non-null   float64
#  4   temperature_2m_min            3653 non-null   float64
#  5   temperature_2m_mean           3653 non-null   float64
#  6   windspeed_10m_max             3653 non-null   float64
#  7   windgusts_10m_max             3653 non-null   float64
#  8   winddirection_10m_dominant    3653 non-null   int64
#  9   shortwave_radiation_sum       3653 non-null   float64
#  10  et0_fao_evapotranspiration    3653 non-null   float64
#  11  weathercode                   3653 non-null   int64
#  12  pressure_msl_mean             3653 non-null   float64
#  13  pressure_msl_min              3653 non-null   float64
#  14  pressure_msl_max              3653 non-null   float64
#  15  surface_pressure_mean         3653 non-null   float64
#  16  relative_humidity_2m_mean     3653 non-null   float64
#  17  relative_humidity_2m_max      3653 non-null   int64
#  18  dew_point_2m_mean             3653 non-null   float64
#  19  dew_point_2m_min              3653 non-null   float64
#  20  vapour_pressure_deficit_mean  3653 non-null   float64
#  21  vapour_pressure_deficit_min   3653 non-null   float64
#  22  cloud_cover_mean              3653 non-null   float64
#  23  cloud_cover_max               3653 non-null   int64
#  24  cloud_cover_low_mean          3653 non-null   float64
#  25  cloud_cover_low_max           3653 non-null   int64
#  26  cloud_cover_mid_mean          3653 non-null   float64
#  27  cloud_cover_high_mean         3653 non-null   float64
#  28  wind_speed_10m_mean           3653 non-null   float64
#  29  wind_speed_10m_max            3653 non-null   float64
#  30  wind_direction_10m_mean       3653 non-null   float64
#  31  wind_gusts_10m_max            3653 non-null   float64
#  32  pressure_trend_24h            3652 non-null   float64
#  33  pressure_trend_48h            3651 non-null   float64
#  34  pressure_range                3653 non-null   float64
#  35  wind_west_component           3653 non-null   float64
#  36  wind_north_component          3653 non-null   float64
#  37  rh_vpd_interaction            3653 non-null   float64
# dtypes: datetime64[ns](1), float64(32), int64(5)
# memory usage: 1.1 MB

# %%
# Generar tabla con la cantidad de registros por año
registros_por_anio = df.groupby(df['fecha'].dt.year).size().reset_index(name='días')
display(registros_por_anio)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fecha</th><th>días</th></tr></thead><tbody><tr><td>2016</td><td>366</td></tr><tr><td>2017</td><td>365</td></tr><tr><td>2018</td><td>365</td></tr><tr><td>2019</td><td>365</td></tr><tr><td>2020</td><td>366</td></tr><tr><td>2021</td><td>365</td></tr><tr><td>2022</td><td>365</td></tr><tr><td>2023</td><td>365</td></tr><tr><td>2024</td><td>366</td></tr><tr><td>2025</td><td>365</td></tr></tbody></table></div>

# %%
save_to_delta_table(df, "weather_raw", spark)
# Out:
# ✅ Guardado en tabla Delta: weather_raw (3653 filas, 38 columnas)
